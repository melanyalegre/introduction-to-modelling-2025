# %%
import pandas as pd
Age_Income=pd.read_csv('/Users/melanyalegre/Downloads/Age_Income.csv')

# %% [markdown]
# exercise 1

# %%
Age_Income.head()
# Out:
#    Age  Income  Experience
# 0   30   50000           6
# 1   27   40000           4
# 2   26   30000           2
# 3   29   45000           4
# 4   20   35000           3

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.formula.api as sm
model1=sm.ols('Income~Age', data=Age_Income).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     15.13
# Date:                Wed, 10 Sep 2025   Prob (F-statistic):            0.00461
# Time:                        13:25:49   Log-Likelihood:                -101.62
# No. Observations:                  10   AIC:                             207.2
# Df Residuals:                       8   BIC:                             207.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -9362.0690   1.09e+04     -0.858      0.416   -3.45e+04    1.58e+04
# ...

# %% [markdown]
# exercise 2

# %%
model1=sm.ols('Income~Experience',data=Age_Income).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     42.14
# Date:                Wed, 10 Sep 2025   Prob (F-statistic):           0.000190
# Time:                        13:30:52   Log-Likelihood:                -97.752
# No. Observations:                  10   AIC:                             199.5
# Df Residuals:                       8   BIC:                             200.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.658e+04   2838.090      5.842      0.000       1e+04    2.31e+04
# ...

# %% [markdown]
# Homework for class 1
