# %%
#Week 2 - Stork and Babies
import pandas as pd

Stork_Data = pd.read_csv("/Users/melanyalegre/Downloads/Stork_Data.csv")

# %%
Stork_Data.head()
# Out:
#     Country  LandArea  StorkPairs  Humans  BirthRate
# 0   Albania     28750         100     3.2         83
# 1   Austria     83860         300     7.6         87
# 2   Belgium     30250           1     9.9        118
# 3  Bulgaria    111000        5000     9.0        117
# 4   Denmark     43100           9     5.1         59

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.formula.api as sm

# %%
model1=sm.ols('BirthRate~StorkPairs+LandArea', data=Stork_Data).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              BirthRate   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     43.77
# Date:                Tue, 16 Sep 2025   Prob (F-statistic):           9.48e-07
# Time:                        09:54:39   Log-Likelihood:                -109.04
# No. Observations:                  17   AIC:                             224.1
# Df Residuals:                      14   BIC:                             226.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -7.4996     56.723     -0.132      0.897    -129.158     114.159
# ...

# %%
import pandas as pd

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from statsmodels.tools.tools import add_constant

# %%
UniversitySalaries=pd.read_excel('/Users/melanyalegre/Downloads/University Salaries.xlsx')

# %%
x=UniversitySalaries=[['Age','Experience','Student_Approval']].dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 x=UniversitySalaries=[['Age','Experience','Student_Approval']].dropna()
#
# AttributeError: 'list' object has no attribute 'dropna'
