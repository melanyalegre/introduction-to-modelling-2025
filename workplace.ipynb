# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 12.7 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 9.6 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
StudentsPerformance=pd.read_csv('/Users/melanyalegre/Downloads/StudentsPerformance.csv')

# %%
StudentsPerformance.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 11.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 13.8 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
reading_score=StudentsPerformance['reading_score']
math_score=StudentsPerformance['math_score']
plt.scatter(reading_score,math_score)

# %%
pip install scipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 16.1 MB/s  0:00:01 eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy.stats
scipy.stats.pearsonr(reading_score,math_score)
# Out:
# PearsonRResult(statistic=np.float64(0.8175796636720543), pvalue=np.float64(1.7877531099052406e-241))

# %%
reading_score=StudentsPerformance['reading_score']
writing_score=StudentsPerformance['writing_score']
plt.scatter(reading_score,writing_score)

# %%
scipy.stats.pearsonr(reading_score,writing_score)
# Out:
# PearsonRResult(statistic=np.float64(0.9545980771462479), pvalue=np.float64(0.0))

# %%
data=StudentsPerformance[['reading_score','writing_score','math_score']]
matrix=data.corr()
print(matrix)
# Out:
#                reading_score  writing_score  math_score
# reading_score       1.000000       0.954598    0.817580
# writing_score       0.954598       1.000000    0.802642
# math_score          0.817580       0.802642    1.000000

# %%
pip install seaborn
# Out:
# 1374.43s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sn 
sn.heatmap(matrix,annot=True)
# Out:
# <Axes: >

# %%
sn.pairplot(StudentsPerformance)
