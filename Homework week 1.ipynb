# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Exercise 1

# %%
import pandas as pd

# %%
WorldHappiness=pd.read_csv('/Users/melanyalegre/Downloads/World Happiness 2019.csv')

# %%
WorldHappiness.head()
# Out:
#    Overall_rank Country_or_region  Happiness_Score  GDP_per_capita  \
# 0             1           Finland            7.769           1.340
# 1             2           Denmark            7.600           1.383
# 2             3            Norway            7.554           1.488
# 3             4           Iceland            7.494           1.380
# 4             5       Netherlands            7.488           1.396
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions_of_corruption
# 0       0.153                      0.393
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
Happiness_Score=WorldHappiness['Happiness_Score']
GDP_per_capita=WorldHappiness['GDP_per_capita']
plt.scatter(Happiness_Score,GDP_per_capita)
plt.title('Happiness and GDP')
plt.xlabel('GDP per capita')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy.stats

# %%
scipy.stats.pearsonr(Happiness_Score,GDP_per_capita)
# Out:
# PearsonRResult(statistic=np.float64(0.7938828678781276), pvalue=np.float64(4.3154809133194047e-35))

# %%
data=WorldHappiness[['Happiness_Score','GDP_per_capita']]
matrix=data.corr()
print(matrix)
# Out:
#                  Happiness_Score  GDP_per_capita
# Happiness_Score         1.000000        0.793883
# GDP_per_capita          0.793883        1.000000

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sn 
sn.heatmap(matrix,annot=True)
# Out:
# <Axes: >

# %%
sn.pairplot(WorldHappiness)

# %% [markdown]
# Exercise 2: videogames

# %%
video_games=pd.read_excel('/Users/melanyalegre/Downloads/video_games .xlsx')

# %%
video_games.head()
# Out:
#     Sales  Review_Score  Used_Price  Release_Year  \
# 0  4690.0            85       24.95          2004
# 1   560.0            89       14.95          2004
# 2   540.0            81       22.95          2004
# 3   490.0            81       12.95          2004
# 4   450.0            61       14.95          2004
#
#    Length_All_PlayStyles_Polled
# 0                            57
# 1                             5
# 2                            57
# 3                             0
# 4                            37

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Model 1
import statsmodels.formula.api as sm
model1=sm.ols('Sales~Review_Score',data=video_games).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     117.2
# Date:                Sat, 13 Sep 2025   Prob (F-statistic):           4.01e-26
# Time:                        16:12:29   Log-Likelihood:                -10077.
# No. Observations:                1207   AIC:                         2.016e+04
# Df Residuals:                    1205   BIC:                         2.017e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -1188.9206    159.225     -7.467      0.000   -1501.310    -876.531
# ...

# %% [markdown]
# #Model 2
# model2=
